# %% [markdown]
# ## Contents
# * [1. Baseline & Improved Models](#1.-Baseline-&-Improved-Models)
# * [2. Read & Clean Data](#2.-Read-&-Clean-Data)
# * [3. Baseline Model](#3.-Baseline-Model)
# * [4. Improved Model 1](#4.-Improved-Model-1)

# %% [markdown]
# ---
# ## 1. Baseline & Improved Models
# ---
# To develop:
# - Baseline model: an ARIMA model on dengue data
# - Improved model 1: an improved ARIMAX model on dengue data, using weather, google search trends, and COVID-19 circuit breaker phases to model human freedom (engineered feature to model disease vector density)
#
# |            | Baseline                          | Improved 1                                                                                                                                                                |
# |------------------|-----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Model            | ARIMA                             | ARIMAX                                                                                                                                                                    |
# | Training data            | - 2013 - 2021 monthly dengue data | - 2013 - 2021 monthly dengue data<br>- Weather<br>- Google trends<br>- Circuit breaker phases |
# | Test data | year of 2022               | year of 2022        |

# %% [markdown]
# ---
# ## 2. Read & Clean Data
# ---

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (3.1.0)
# Requirement already satisfied: et-xmlfile in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from openpyxl) (1.1.0)

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (2.0.2)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: urllib3 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: pandas>=0.19 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (0.29.33)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.1.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (65.5.1)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pmdarima) (1.22.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in c:\users\edmon\.conda\envs\dsi-sg\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.metrics import mean_absolute_percentage_error # metric that's used to evaluate the performance of a time series model
import pmdarima as pm
from sklearn.preprocessing import StandardScaler, PowerTransformer
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from pmdarima.arima import ADFTest
import os

# %% [markdown]
# ### Reading csvs for dengue, weather and google_trends

# %%
dengue = pd.read_csv('data/input/Dengue_monthly.csv')
weather = pd.read_csv('data/input/weather_csv.csv')
google_trends = pd.read_csv('data/output/googletrends_clean.csv')

# %% [markdown]
# ---
# ## 3. Baseline Model
# ---

# %% [markdown]
# We first start by using dengue by itself without any Exogenous features.<br>

# %%
#set year_month as datetime 
dengue['Year_Month'] = pd.to_datetime(dengue['Year_Month'], format='%Y.%m.%d')

# %% [markdown]
# We decided to train our data only from 2013 onwards as our Exogenous features from weather data were only from 2013 onwards.

# %%
#set year_month as index
dengue.set_index('Year_Month', inplace=True)

# %%
dengue = dengue.loc[dengue.index >= '2013']

# %%
#split it to 90 :10 split 
y_train, y_test = train_test_split(dengue['Dengue'], test_size=.1, shuffle=False)

# %%
arima_model = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           # the commented parameters below will be used in the next lesson (advanced time series)
                           # start_P=0, max_P=10,
                           # D=None,
                           # start_Q=0, max_Q=10,
                           # m=12, # For monthly data since the pattern repeats every 12 months
                           # seasonal=True,
                           trace=True, # Print values in console for each fit in the grid search
                           random=True, # to not perform an exhaustive search & set an internal stop (refer doc)
                           random_state=20, # repeatability of steps in the same order
                           n_fits=50 # max no. of ARIMA models fits, the algorithm MUST stop at the end of 50 fits
                          )

arima_model.fit(y_train) # only fit on the one column that we have, y_train
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1832.213, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1704.157, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1748.598, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1907.878, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1696.900, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1698.882, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1698.895, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1698.511, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1700.889, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1703.504, Time=0.04 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.545 seconds
# AutoARIMA(max_p=10, max_q=10, n_fits=50, random=True, random_state=20,
#           start_p=0, start_q=0, trace=True)

# %%
y_pred = arima_model.predict(n_periods = len(y_test)) # we want as many future predictions as there are in y_test

# %%
# Plot predictions to compare vs y_test.
plt.figure(figsize=(30,15))

# Plot training data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
plt.plot(y_train, color='blue', label='y_train')

# Plot testing data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
plt.plot(y_test, color='orange', label='y_test', alpha = 0.7)

# Plot predicted test values. no index in y_pred as shown above, need to explicitly pass to compare for same timeframe as y_test
plt.plot(y_test.index, y_pred, color='green', label='y_pred', alpha = 0.9, ls = '--')

plt.title(label = 'ARIMA predictions', fontsize=16)
plt.legend(fontsize = 20, loc = 'upper left');
mape = mean_absolute_percentage_error(y_test, y_pred)

plt.title(label = f'ARIMA predictions\n MAPE: {mape:.2f}', fontsize=16) #\n is just for new line to print MAPE 1 line after header 'Sales Predictions', while .2f rounds MAPE to 2 decimals
plt.legend(fontsize = 20, loc = 'upper left'); # for legend to be displayed in our plot

# %% [markdown]
# ---
# ## 4. Improved Model 1
# ---

# %% [markdown]
# ### setting google_trends as the index as well as formatting the date

# %%
google_trends['date'] = pd.to_datetime(google_trends['date'],format = '%Y.%m.%d')

# %%
google_trends.set_index('date',inplace=True)

# %%
google_trends.sort_index(inplace=True)

# %% [markdown]
# ### join weather, google_trends and dengue

# %%
weather['Date'] = pd.to_datetime(weather['Date'],format = '%Y.%m.%d')

# %%
weather.set_index('Date',inplace=True)

# %%
weather.sort_index(inplace=True)

# %%
dengue_weather_google = weather.join([dengue,google_trends])

# %%
dengue_weather_google_2 = dengue_weather_google.copy()

# %% [markdown]
# ### Using the features of dengue_weather_google_2 make feature called "human_restrictions"
# 1: Pre-COVID (< 31 Dec 2019 and > 8 May 2021)
#
# 2: Phase 3 reopening (28 December 2020 - 8 May 2021 OR 1 Jan 2020 - 6 April 2020)
#
# 3: Phase 1+2 reopening (2 June 2020 - 27 December 2020)
#
# 4: Circuit breaker period (7 April 2020 – 1 June 2020)

# %%
dengue_weather_google_2['human_restrictions'] = 0
dengue_weather_google_2.loc[(dengue_weather_google_2.index < '2020-12-31') | (dengue_weather_google_2.index > '2021-05-08'), 'human_restrictions'] = 1
dengue_weather_google_2.loc[((dengue_weather_google_2.index >= '2020-12-28') & (dengue_weather_google_2.index <= '2021-05-08')) | ((dengue_weather_google_2.index>= '2020-01-01') & (dengue_weather_google_2.index<= '2020-04-06')), 'human_restrictions'] = 2
dengue_weather_google_2.loc[(dengue_weather_google_2.index >= '2020-06-02') & (dengue_weather_google_2.index <= '2020-12-27'), 'human_restrictions'] = 3
dengue_weather_google_2.loc[(dengue_weather_google_2.index >= '2020-04-07') & (dengue_weather_google_2.index <= '2020-06-01'), 'human_restrictions'] = 4

# %% [markdown]
# ### Functions for use
#
# x_y seperates our dengue from our Exogenous features.

# %%
def x_y(z):
    y = z['Dengue']
    x = z.drop(columns = 'Dengue')
    return y,x

# %%
dengue_weather_google_2
# Out:
#             mean_temp  no_rain_day  mean_humidity  mean_sunshine_hour  \
# Date
# 2013-01-01       27.1           15           82.1                 6.0
# 2013-02-01       26.5           22           86.9                 4.0
# 2013-03-01       28.3           10           80.4                 7.5
# 2013-04-01       28.2           19           82.7                 5.2
# 2013-05-01       28.2           17           83.1                 5.4
# ...               ...          ...            ...                 ...
# 2022-08-01       28.1           15           77.4                 5.5
# 2022-09-01       27.9           14           76.9                 3.8
# 2022-10-01       27.6           27           78.7                 3.5
# 2022-11-01       27.4           26           79.9                 3.8
# 2022-12-01       26.8           19           81.2                 3.6
#
#             normal_dengue  dhf  dengue_total  Dengue  DHF  dengue symptoms  \
# Date
# 2013-01-01            979    5           984     979    5               11
# 2013-02-01           1109    5          1114    1109    5               20
# 2013-03-01           1600   10          1610    1600   10               13
# 2013-04-01           2079    7          2086    2079    7               40
# 2013-05-01           2546    9          2555    2546    9               47
# ...                   ...  ...           ...     ...  ...              ...
# 2022-08-01           2796    5          2801    2796    5               31
# 2022-09-01           2012    1          2013    2012    1               25
# 2022-10-01           1778    2          1780    1778    2               21
# 2022-11-01           1116    3          1119    1116    3               15
# 2022-12-01            887    2           889    1172    2               16
#
#             dengue fever  dengue how  dengue mosquito  mosquito bite  \
# Date
# 2013-01-01            20           2                0              4
# 2013-02-01            35           3                6              4
# 2013-03-01            26           2                4              6
# 2013-04-01            50           4               14              7
# 2013-05-01            54           5               10              3
# ...                  ...         ...              ...            ...
# 2022-08-01            14           6                4              5
# 2022-09-01            14           5                5              5
# 2022-10-01            10           4                3              6
# 2022-11-01            10           2                5              5
# 2022-12-01             8           2                1              4
#
#             human_restrictions
# Date
# 2013-01-01                   1
# 2013-02-01                   1
# 2013-03-01                   1
# 2013-04-01                   1
# 2013-05-01                   1
# ...                        ...
# 2022-08-01                   1
# 2022-09-01                   1
# 2022-10-01                   1
# 2022-11-01                   1
# 2022-12-01                   1
#
# [120 rows x 15 columns]

# %%
#after shift joined back to dengue
shifted_dengue_weather_google_2 = dengue_weather_google_2.drop(columns='Dengue').shift().join(dengue_weather_google['Dengue'])

# %%
shifted_dengue_weather_google_2.dropna(inplace=True)
train = shifted_dengue_weather_google_2[:'2021']
test = shifted_dengue_weather_google_2['2022':]

# %%
train_transformer = StandardScaler()
test_transformer = StandardScaler()


train_scale = train_transformer.fit_transform(train)
test_scale = test_transformer.fit_transform(test)

test_scaled = pd.DataFrame(test_scale, columns = test.columns).set_index(test.index)
train_scaled = pd.DataFrame(train_scale, columns = shifted_dengue_weather_google_2.columns).set_index(train.index)

# %%
def plot_forecast(y_train, y_test, z, X_test=None):
    # Generate len(y_test) number of predictions
    y_pred = z.predict(n_periods = len(y_test), X=X_test) # we want as many future data point predictions as there are in y_test
    print(y_pred)
    # Plot data.
    plt.figure(figsize=(30,15))

    # Plot training data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
    plt.plot(y_train, color='blue', label='y_train')

    # Plot testing data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
    plt.plot(y_test, color='orange', label='y_test', alpha = 0.7)

    # Plot predicted test values. as shared previously, there are no index in y_pred 
    # so, we need to explicitly pass the `x-axis` (dates) to compare for same timeframe as y_test and access y_pred vs actual y_test
    # we can use y_test.index to get the index of y_test as confirmed earlier in y_test.head()
    plt.plot(y_test.index, y_pred, color='green', label='y_pred', alpha = 0.9, ls = '--')
    
    # Find the MAPE (mean abs percentage error) of the predictions
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
    mape = mean_absolute_percentage_error(y_test, y_pred) # like all sklearn metrics we've used, pass y_actual, y_pred

    plt.title(label = f'ARIMA predictions\n MAPE: {mape:.2f}', fontsize=16) #\n is just for new line to print MAPE 1 line after header 'Sales Predictions', while .2f rounds MAPE to 2 decimals
    plt.legend(fontsize = 20, loc = 'upper left');

# %%
train_y, train_x = x_y(train_scaled)
test_y, test_x = x_y(test_scaled)

# %%
arima_model_human = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           start_P=0, max_P=10,
                           D=None,
                           start_Q=0, max_Q=10, 
                           trace=True, # Print values for each fit in the grid search
                           random=True,
                           random_state=20,
                           n_fits=300
                          )

arima_model_human.fit(train_y, train_x)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=183.359, Time=0.19 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=169.068, Time=0.30 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=181.294, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=181.359, Time=0.14 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=168.078, Time=0.41 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=170.066, Time=0.43 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=170.072, Time=0.64 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=168.475, Time=0.46 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=171.370, Time=0.70 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=166.079, Time=0.32 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=167.071, Time=0.28 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=168.067, Time=0.44 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=168.073, Time=0.50 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=166.476, Time=0.42 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=169.370, Time=0.74 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 6.268 seconds
# AutoARIMA(max_P=10, max_Q=10, max_p=10, max_q=10, n_fits=300, random=True,
#           random_state=20, start_P=0, start_Q=0, start_p=0, start_q=0,
#           trace=True)

# %%
plot_forecast(train_y, test_y, arima_model_human, test_x)
# Out:
# 2022-01-01   -0.736452
# 2022-02-01   -0.581644
# 2022-03-01   -0.555523
# 2022-04-01   -0.262524
# 2022-05-01    0.171423
# 2022-06-01    0.471128
# 2022-07-01    0.264407
# 2022-08-01    0.323534
# 2022-09-01   -0.288497
# 2022-10-01   -0.642810
# 2022-11-01   -0.217204
# 2022-12-01   -0.200280
# Freq: MS, dtype: float64

# %%
y_train, y_test = train_test_split(dengue['Dengue'], test_size=.1, shuffle=False)

# %%
arima_model = pm.AutoARIMA(start_p=0, max_p=10, 
                           d=None,    # find optimum value of d automatically
                           start_q=0, max_q=10,
                           # the commented parameters below will be used in the next lesson (advanced time series)
                           # start_P=0, max_P=10,
                           # D=None,
                           # start_Q=0, max_Q=10,
                           # m=12, # For monthly data since the pattern repeats every 12 months
                           # seasonal=True,
                           trace=True, # Print values in console for each fit in the grid search
                           random=True, # to not perform an exhaustive search & set an internal stop (refer doc)
                           random_state=20, # repeatability of steps in the same order
                           n_fits=50 # max no. of ARIMA models fits, the algorithm MUST stop at the end of 50 fits
                          )

arima_model.fit(y_train) # only fit on the one column that we have, y_train
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1832.213, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1704.157, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1748.598, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1907.878, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1696.900, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1698.882, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1698.895, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1698.511, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1700.889, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1703.504, Time=0.04 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.528 seconds
# AutoARIMA(max_p=10, max_q=10, n_fits=50, random=True, random_state=20,
#           start_p=0, start_q=0, trace=True)

# %% [markdown]
# ### Analysis

# %% [markdown]
# We can see that as compared to the baseline, our model performed worse with all our additional features when observing the MAPE score increasing.
#
# |            | Baseline                          | Improved 1                                                                                                                                                                |
# |------------------|-----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Model            | ARIMA                             | ARIMAX                                                                                                                                                                    |
# | Training data             | - 2013 - 2021 monthly dengue data | - 2013 - 2021 monthly dengue data<br>- Weather<br>- Google trends<br>- Circuit breaker phases |
# | Testing data | year of 2022               | year of 2022                                                                                                                                                       |
# | MAPE score       | 0.47                              | 0.91                                                                                                                                                                      |
